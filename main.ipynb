# %%
from bs4 import BeautifulSoup
from functions import ParserCategory
import requests, os, shutil

# %%
URL = "https://skybrary.aero"
webSite = requests.get(URL)
soup = BeautifulSoup(webSite.content, "html.parser")

dict_navigations={}

# find all a tags in div with class="sf-depth-1 menuparent" or "sf-depth-1" (navigation bar)
navigations = soup.find_all("a", class_=["sf-depth-1 menuparent", "sf-depth-1"])
for navigation in navigations:
    dict_navigations[navigation.text.strip()] = URL + navigation["href"]

dict_navigations
# Out:
# {'Portals': 'https://skybrary.aero/portals',
#  'Browsers': 'https://skybrary.aero/browsers',
#  'Themes': 'https://skybrary.aero/themes-0',
#  'Tutorials': 'https://skybrary.aero/tutorials',
#  'Courses': 'https://skybrary.aero/courses',
#  'Publications': 'https://skybrary.aero/publications'}

# %%
portals_page = requests.get(dict_navigations["Portals"])
portals_soup = BeautifulSoup(portals_page.content, "html.parser")

# find all a tags in div with class="term-name"
portal_categories = portals_soup.find_all("div", class_="term-name")

array_portal_categories=[]
for portal_category in portal_categories:
    # add link to array_portal_categories
    array_portal_categories.append([URL + portal_category.find("a")["href"], portal_category.text.strip()])

array_portal_categories
# Out:
# [['https://skybrary.aero/operational-issues/air-ground-communication',
#   'Air Ground Communication'],
#  ['https://skybrary.aero/operational-issues/airspace-infringement',
#   'Airspace Infringement'],
#  ['https://skybrary.aero/operational-issues/wildlife-strike',
#   'Wildlife Strike'],
#  ['https://skybrary.aero/operational-issues/controlled-flight-terrain',
#   'Controlled Flight Into Terrain'],
#  ['https://skybrary.aero/operational-issues/fire-smoke-and-fumes',
#   'Fire Smoke and Fumes'],
#  ['https://skybrary.aero/operational-issues/ground-operations',
#   'Ground Operations'],
#  ['https://skybrary.aero/operational-issues/airworthiness', 'Airworthiness'],
#  ['https://skybrary.aero/operational-issues/level-bust', 'Level Bust'],
#  ['https://skybrary.aero/operational-issues/loss-control', 'Loss of Control'],
#  ['https://skybrary.aero/operational-issues/loss-separation',
#   'Loss of Separation'],
#  ['https://skybrary.aero/operational-issues/runway-excursion',
#   'Runway Excursion'],
#  ['https://skybrary.aero/operational-issues/runway-incursion',
#   'Runway Incursion'],
#  ['https://skybrary.aero/operational-issues/wake-vortex-turbulence',
#   'Wake Vortex Turbulence'],
#  ['https://skybrary.aero/operational-issues/weather', 'Weather'],
#  ['https://skybrary.aero/operational-issues/emergency-and-contingency',
#   'Emergency and Contingency'],
#  ['https://skybrary.aero/operational-issues/unmanned-aerial-systems',
#   'Unmanned Aerial Systems'],
#  ['https://skybrary.aero/human-performance/human-behaviour',
#   'Human Behaviour'],
#  ['https://skybrary.aero/human-performance/design-philosophy',
#   'Design Philosophy'],
#  ['https://skybrary.aero/human-performance/human-performance-modelling',
#   'Human Performance Modelling'],
#  ['https://skybrary.aero/human-performance/organisation-and-human-performance',
#   'Organisation and Human Performance'],
#  ['https://skybrary.aero/human-performance/human-factors-training',
#   'Human Factors Training'],
#  ['https://skybrary.aero/human-performance/aeromedical', 'Aeromedical'],
#  ['https://skybrary.aero/human-performance/oghfa', 'OGHFA'],
#  ['https://skybrary.aero/enhancing-safety/cabin-safety', 'Cabin Safety'],
#  ['https://skybrary.aero/enhancing-safety/flight-technical',
#   'Flight Technical'],
#  ['https://skybrary.aero/enhancing-safety/safety-management',
#   'Safety Management'],
#  ['https://skybrary.aero/enhancing-safety/safety-nets', 'Safety Nets'],
#  ['https://skybrary.aero/enhancing-safety/theory-flight', 'Theory of Flight'],
#  ['https://skybrary.aero/enhancing-safety/safety-culture', 'Safety Culture'],
#  ['https://skybrary.aero/enhancing-safety/just-culture', 'Just Culture'],
#  ['https://skybrary.aero/enhancing-safety/icao-adrep', 'ICAO ADREP'],
#  ['https://skybrary.aero/enhancing-safety/cast-safety-enhancements',
#   'CAST Safety Enhancements'],
#  ['https://skybrary.aero/enhancing-safety/accident-investigation',
#   'Accident Investigation'],
#  ['https://skybrary.aero/enhancing-safety/helicopter-safety',
#   'Helicopter Safety'],
#  ['https://skybrary.aero/enhancing-safety/sm-icg-safety-management-products',
#   'SM ICG Safety Management Products'],
#  ['https://skybrary.aero/safety-regulations/rules', 'Rules'],
#  ['https://skybrary.aero/safety-regulations/certification', 'Certification'],
#  ['https://skybrary.aero/safety-regulations/personnel-licensing',
#   'Personnel Licensing'],
#  ['https://skybrary.aero/safety-regulations/monitoring-oversight',
#   'Monitoring & Oversight'],
#  ['https://skybrary.aero/safety-regulations/single-european-sky',
#   'Single European Sky'],
#  ['https://skybrary.aero/safety-regulations/esarrs', 'ESARRs'],
#  ['https://skybrary.aero/safety-regulations/human-error-aviation-and-legal-process',
#   'Human Error in Aviation and Legal Process']]

# %%
for category in array_portal_categories:
    ParserCategory(category[0], category[1])
# Out:
# PARSING: https://skybrary.aero/operational-issues/air-ground-communication
# Number of articles: 71
# PARSING: https://skybrary.aero/operational-issues/airspace-infringement
# Number of articles: 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 for category in array_portal_categories:
# ----> 2     ParserCategory(category[0], category[1])
#
# File ~/Documents/EUROCONTROL/WebScrapping/functions.py:41, in ParserCategory(URL, name_category)
#      38 for article in articles:
#      40     URL_article = "https://skybrary.aero" + article.find("a")["href"]
# ---> 41     webSite_article = requests.get(URL_article)
#      42     soup_article = BeautifulSoup(webSite_article.content, "html.parser")
#      44     # Collect all <div> with class="group-left-bottom" (in fact there is only one)
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:445, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     440             httplib_response = conn.getresponse()
#     441         except BaseException as e:
#     442             # Remove the TypeError from the exception chain in
#     443             # Python 3 (including for exceptions like SystemExit).
#     444             # Otherwise it looks like a bug in the code.
# --> 445             six.raise_from(e, None)
#     446 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:440, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     437 except TypeError:
#     438     # Python 3
#     439     try:
# --> 440         httplib_response = conn.getresponse()
#     441     except BaseException as e:
#     442         # Remove the TypeError from the exception chain in
#     443         # Python 3 (including for exceptions like SystemExit).
#     444         # Otherwise it looks like a bug in the code.
#     445         six.raise_from(e, None)
#
# File /usr/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
browsers_page = requests.get(dict_navigations["Browsers"])
browsers_soup = BeautifulSoup(browsers_page.content, "html.parser")

# find all <a> tags in div with class="filed-item"
browsers = browsers_soup.find("div", class_="group-inner").find_all("a")
browsers

array_browsers=[]
for browser in browsers:
    array_browsers.append([URL + browser["href"], browser.text.strip()])

array_browsers
# Out:
# [['https://skybrary.aero/accidents-and-incidents', 'Accidents and Incidents'],
#  ['https://skybrary.aero/aircraft-types', 'Aircraft types'],
#  ['https://skybrary.aero/airports', 'Airports'],
#  ['https://skybrary.aero/territories', 'ICAO Member States and Territories'],
#  ['https://skybrary.aero/operators', 'Aircraft operators'],
#  ['https://skybrary.aero/bookshelf-items', 'Bookshelf']]

# %%
# ACCIDENTS AND INCIDENTS
print(array_browsers[0])
ParserCategory(array_browsers[0][0], array_browsers[0][1])
# Out:
# ['https://skybrary.aero/accidents-and-incidents', 'Accidents and Incidents']
# PARSING: https://skybrary.aero/accidents-and-incidents
# Nombre de pages: 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 # ACCIDENTS AND INCIDENTS
#       2 print(array_browsers[0])
# ----> 3 ParserCategory(array_browsers[0][0], array_browsers[0][1])
#
# File ~/Documents/EUROCONTROL/WebScrapping/functions.py:19, in ParserCategory(URL, name_category)
#      17 for i in range(int(number_of_pages)):
#      18     category_page = requests.get(URL+"?items_per_page=100&page="+str(i))
# ---> 19     category_soup = BeautifulSoup(category_page.content, "html.parser")
#      20     div_articles = category_soup.find_all("div", class_="title")
#      21     span_articles = category_soup.find_all("span", class_="field-content")
#
# File ~/.local/lib/python3.11/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File ~/.local/lib/python3.11/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File ~/.local/lib/python3.11/site-packages/bs4/builder/_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381 except AssertionError as e:
#     382     # html.parser raises AssertionError in rare cases to
#     383     # indicate a fatal problem with the markup, especially
#     384     # when there's an error in the doctype declaration.
#     385     raise ParserRejectedMarkup(e)
#
# File /usr/lib/python3.11/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File /usr/lib/python3.11/html/parser.py:172, in HTMLParser.goahead(self, end)
#     170     k = self.parse_starttag(i)
#     171 elif startswith("</", i):
# --> 172     k = self.parse_endtag(i)
#     173 elif startswith("<!--", i):
#     174     k = self.parse_comment(i)
#
# File /usr/lib/python3.11/html/parser.py:413, in HTMLParser.parse_endtag(self, i)
#     410         self.handle_data(rawdata[i:gtpos])
#     411         return gtpos
# --> 413 self.handle_endtag(elem)
#     414 self.clear_cdata_mode()
#     415 return gtpos
#
# File ~/.local/lib/python3.11/site-packages/bs4/builder/_htmlparser.py:176, in BeautifulSoupHTMLParser.handle_endtag(self, name, check_already_closed)
#     174     self.already_closed_empty_element.remove(name)
#     175 else:
# --> 176     self.soup.handle_endtag(name)
#
# File ~/.local/lib/python3.11/site-packages/bs4/__init__.py:770, in BeautifulSoup.handle_endtag(self, name, nsprefix)
#     764 """Called by the tree builder when an ending tag is encountered.
#     765
#     766 :param name: Name of the tag.
#     767 :param nsprefix: Namespace prefix for the tag.
#     768 """
#     769 #print("End tag: " + name)
# --> 770 self.endData()
#     771 self._popToTag(name, nsprefix)
#
# File ~/.local/lib/python3.11/site-packages/bs4/__init__.py:616, in BeautifulSoup.endData(self, containerClass)
#     611 if self.parse_only and len(self.tagStack) <= 1 and \
#     612        (not self.parse_only.text or \
#     613         not self.parse_only.search(current_data)):
#     614     return
# --> 616 containerClass = self.string_container(containerClass)
#     617 o = containerClass(current_data)
#     618 self.object_was_parsed(o)
#
# File ~/.local/lib/python3.11/site-packages/bs4/__init__.py:523, in BeautifulSoup.string_container(self, base_class)
#     517     kwattrs.update(attrs)
#     518     return self.element_classes.get(Tag, Tag)(
#     519         None, self.builder, name, namespace, nsprefix, kwattrs,
#     520         sourceline=sourceline, sourcepos=sourcepos
#     521     )
# --> 523 def string_container(self, base_class=None):
#     524     container = base_class or NavigableString
#     526     # There may be a general override of NavigableString.
#
# KeyboardInterrupt:

# %%
# AIRCRAFT
print(array_browsers[1])
ParserCategory(array_browsers[1][0], array_browsers[1][1])
# Out:
# ['https://skybrary.aero/aircraft-types', 'Aircraft types']
# PARSING: https://skybrary.aero/aircraft-types
# (List of articles) Number of pages: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # AIRCRAFT
#       2 print(array_browsers[1])
# ----> 3 ParserCategory(array_browsers[1][0], array_browsers[1][1])
#
# File ~/Documents/EUROCONTROL/WebScrapping/functions.py:23, in ParserCategory(URL, name_category)
#      20 print("(List of articles) Number of pages: "+str(number_of_pages))
#      22 for i in range(int(number_of_pages)):
# ---> 23     category_page = requests.get(URL+"?items_per_page=100&page="+str(i))
#      24     category_soup = BeautifulSoup(category_page.content, "html.parser")
#      25     div_articles = category_soup.find_all("div", class_="title")
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:445, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     440             httplib_response = conn.getresponse()
#     441         except BaseException as e:
#     442             # Remove the TypeError from the exception chain in
#     443             # Python 3 (including for exceptions like SystemExit).
#     444             # Otherwise it looks like a bug in the code.
# --> 445             six.raise_from(e, None)
#     446 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:440, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     437 except TypeError:
#     438     # Python 3
#     439     try:
# --> 440         httplib_response = conn.getresponse()
#     441     except BaseException as e:
#     442         # Remove the TypeError from the exception chain in
#     443         # Python 3 (including for exceptions like SystemExit).
#     444         # Otherwise it looks like a bug in the code.
#     445         six.raise_from(e, None)
#
# File /usr/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# AIRPORTS
print(array_browsers[2])
ParserCategory(array_browsers[2][0], array_browsers[2][1])
# Out:
# ['https://skybrary.aero/airports', 'Airports']
# PARSING: https://skybrary.aero/airports
# (List of articles) Number of pages: 48
# Number of articles: 4746
# https://skybrary.aero/airports/leco
# https://skybrary.aero/airports/edka
# https://skybrary.aero/airports/ekyt
# https://skybrary.aero/airports/ekah
# https://skybrary.aero/airports/hajm
# https://skybrary.aero/airports/hadr
# https://skybrary.aero/airports/oiaa
# https://skybrary.aero/airports/lfoi
# https://skybrary.aero/airports/cyxx
# https://skybrary.aero/airports/htza
# https://skybrary.aero/airports/musc
# https://skybrary.aero/airports/diau
# https://skybrary.aero/airports/egpd
# https://skybrary.aero/airports/kabr
# https://skybrary.aero/airports/oeab
# https://skybrary.aero/airports/diap
# https://skybrary.aero/airports/kabi
# https://skybrary.aero/airports/diao
# https://skybrary.aero/airports/oebq
# https://skybrary.aero/airports/mmcs
# https://skybrary.aero/airports/kspi
# https://skybrary.aero/airports/libp
# https://skybrary.aero/airports/oeaa
# https://skybrary.aero/airports/omaa
# https://skybrary.aero/airports/oiba
# https://skybrary.aero/airports/hebl
# https://skybrary.aero/airports/dgaa
# https://skybrary.aero/airports/wars
# https://skybrary.aero/airports/uate
# https://skybrary.aero/airports/padk
# https://skybrary.aero/airports/ltaf
# https://skybrary.aero/airports/ypad
# https://skybrary.aero/airports/warq
# https://skybrary.aero/airports/warj
# https://skybrary.aero/airports/kslk
# https://skybrary.aero/airports/daua
# https://skybrary.aero/airports/lfpl
# https://skybrary.aero/airports/ypec
# https://skybrary.aero/airports/sbct
# https://skybrary.aero/airports/gmad
# https://skybrary.aero/airports/veat
# https://skybrary.aero/airports/lfba
# https://skybrary.aero/airports/faag
# https://skybrary.aero/airports/lgag
# https://skybrary.aero/airports/swhp
# https://skybrary.aero/airports/rora
# https://skybrary.aero/airports/vaah
# https://skybrary.aero/airports/mhah
# https://skybrary.aero/airports/oiaw
# https://skybrary.aero/airports/daas
# https://skybrary.aero/airports/dauu
# https://skybrary.aero/airports/daaq
# https://skybrary.aero/airports/lfda
# https://skybrary.aero/airports/syah
# https://skybrary.aero/airports/lfma
# https://skybrary.aero/airports/lfkj
# https://skybrary.aero/airports/dnen
# https://skybrary.aero/airports/pakh
# https://skybrary.aero/airports/pfak
# https://skybrary.aero/airports/rjsk
# https://skybrary.aero/airports/vaak
# https://skybrary.aero/airports/kcak
# https://skybrary.aero/airports/zwak
# https://skybrary.aero/airports/lgpz
# https://skybrary.aero/airports/uatt
# https://skybrary.aero/airports/dnak
# https://skybrary.aero/airports/biar
# https://skybrary.aero/airports/dnai
# https://skybrary.aero/airports/omal
# https://skybrary.aero/airports/oraa
# https://skybrary.aero/airports/omad
# https://skybrary.aero/airports/orai
# https://skybrary.aero/airports/omrj
# https://skybrary.aero/airports/orub
# https://skybrary.aero/airports/orni
# https://skybrary.aero/airports/omrs
# https://skybrary.aero/airports/orat
# https://skybrary.aero/airports/otbh
# https://skybrary.aero/airports/oeba
# https://skybrary.aero/airports/oesk
# https://skybrary.aero/airports/oewj
# https://skybrary.aero/airports/pauk
# https://skybrary.aero/airports/kalm
# https://skybrary.aero/airports/leab
# https://skybrary.aero/airports/yaba
# https://skybrary.aero/airports/kalb
# https://skybrary.aero/airports/koaj
# https://skybrary.aero/airports/lfaq
# https://skybrary.aero/airports/svmd
# https://skybrary.aero/airports/mutd
# https://skybrary.aero/airports/lfci
# https://skybrary.aero/airports/smbn
# https://skybrary.aero/airports/mpmg
# https://skybrary.aero/airports/kabq
# https://skybrary.aero/airports/ymay
# https://skybrary.aero/airports/leri
# https://skybrary.aero/airports/ueea
# https://skybrary.aero/airports/egja
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # AIRPORTS
#       2 print(array_browsers[2])
# ----> 3 ParserCategory(array_browsers[2][0], array_browsers[2][1])
#
# File ~/Documents/EUROCONTROL/WebScrapping/functions.py:41, in ParserCategory(URL, name_category)
#      38 for article in articles:
#      40     URL_article = "https://skybrary.aero" + article.find("a")["href"]
# ---> 41     webSite_article = requests.get(URL_article)
#      42     soup_article = BeautifulSoup(webSite_article.content, "html.parser")
#      44     print(URL_article)
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:699, in Session.send(self, request, **kwargs)
#     696         pass
#     698 if not stream:
# --> 699     r.content
#     701 return r
#
# File /usr/lib/python3/dist-packages/requests/models.py:831, in Response.content(self)
#     829         self._content = None
#     830     else:
# --> 831         self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     833 self._content_consumed = True
#     834 # don't need to release the connection; that's been handled by urllib3
#     835 # since we exhausted the data.
#
# File /usr/lib/python3/dist-packages/requests/models.py:753, in Response.iter_content.<locals>.generate()
#     751 if hasattr(self.raw, 'stream'):
#     752     try:
# --> 753         for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754             yield chunk
#     755     except ProtocolError as e:
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:572, in HTTPResponse.stream(self, amt, decode_content)
#     556 """
#     557 A generator wrapper for the read() method. A call will block until
#     558 ``amt`` bytes have been read from the connection or until the
#    (...)
#     569     'content-encoding' header.
#     570 """
#     571 if self.chunked and self.supports_chunked_reads():
# --> 572     for line in self.read_chunked(amt, decode_content=decode_content):
#     573         yield line
#     574 else:
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:767, in HTTPResponse.read_chunked(self, amt, decode_content)
#     765 if self.chunk_left == 0:
#     766     break
# --> 767 chunk = self._handle_chunk(amt)
#     768 decoded = self._decode(
#     769     chunk, decode_content=decode_content, flush_decoder=False
#     770 )
#     771 if decoded:
#
# File /usr/lib/python3/dist-packages/urllib3/response.py:711, in HTTPResponse._handle_chunk(self, amt)
#     709     self.chunk_left = None
#     710 elif amt < self.chunk_left:
# --> 711     value = self._fp._safe_read(amt)
#     712     self.chunk_left = self.chunk_left - amt
#     713     returned_chunk = value
#
# File /usr/lib/python3.11/http/client.py:630, in HTTPResponse._safe_read(self, amt)
#     623 def _safe_read(self, amt):
#     624     """Read the number of bytes requested.
#     625
#     626     This function should be used when <amt> bytes "should" be present for
#     627     reading. If the bytes are truly not available (due to EOF), then the
#     628     IncompleteRead exception can be used to detect the problem.
#     629     """
# --> 630     data = self.fp.read(amt)
#     631     if len(data) < amt:
#     632         raise IncompleteRead(data, amt-len(data))
#
# File /usr/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# ICAO member states
print(array_browsers[3])
ParserCategory(array_browsers[3][0], array_browsers[3][1])
# Out:
# ['https://skybrary.aero/territories', 'ICAO Member States and Territories']
# PARSING: https://skybrary.aero/territories
# (List of articles) Number of pages: 3
# Number of articles: 241
# https://skybrary.aero/territories/afghanistan
# https://skybrary.aero/alaska
# https://skybrary.aero/territories/albania
# https://skybrary.aero/territories/algeria
# https://skybrary.aero/american-samoa
# https://skybrary.aero/territories/angola
# https://skybrary.aero/anguilla
# https://skybrary.aero/territories/antigua-and-barbuda
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # ICAO member states
#       2 print(array_browsers[3])
# ----> 3 ParserCategory(array_browsers[3][0], array_browsers[3][1])
#
# File ~/Documents/EUROCONTROL/WebScrapping/functions.py:41, in ParserCategory(URL, name_category)
#      38 for article in articles:
#      40     URL_article = "https://skybrary.aero" + article.find("a")["href"]
# ---> 41     webSite_article = requests.get(URL_article)
#      42     soup_article = BeautifulSoup(webSite_article.content, "html.parser")
#      44     print(URL_article)
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 # Trigger any extra validation we need to do.
#     381 try:
# --> 382     self._validate_conn(conn)
#     383 except (SocketTimeout, BaseSSLError) as e:
#     384     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     385     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1012, in HTTPSConnectionPool._validate_conn(self, conn)
#    1010 # Force connect early to allow us to validate the connection.
#    1011 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1012     conn.connect()
#    1014 if not conn.is_verified:
#    1015     warnings.warn(
#    1016         (
#    1017             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1022         InsecureRequestWarning,
#    1023     )
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     402 if (
#     403     not self.ca_certs
#     404     and not self.ca_cert_dir
#    (...)
#     407     and hasattr(context, "load_default_certs")
#     408 ):
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#     427 if (
#     428     default_ssl_context
#     429     and self.ssl_version is None
#     430     and hasattr(self.sock, "version")
#     431     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     432 ):
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:

# %%
# AIRCRAFT OPERATORS
print(array_browsers[4])
ParserCategory(array_browsers[4][0], array_browsers[4][1])
# Out:
# ['https://skybrary.aero/operators', 'Aircraft operators']
# PARSING: https://skybrary.aero/operators
# Nombre de pages: 7
# Nombre d'articles: 614
# PARSING: https://skybrary.aero/operator/abelag-aviation
# [<div class="group-left two_thirds">
# <div class="group-inner">
# <div class="field field-node-node-title field-name-node-title field-type-ds field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><h2>
#   Abelag Aviation
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="group-left-bottom">
# <div class="group-inner">
# <div class="clearfix text-formatted field field-node-body field-name-body field-type-text-with-summary field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><p>Abelag Aviation is an air charter company based at Brussels airport, Belgium. It operates ad hoc charter, air taxi, cargo and medical flights, as well as helicopter VIP flights and air ambulance work.</p>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents field-type-ds field-label-hidde">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Accidents &amp; Serious Incidents involving operator</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_1 js-view-dom-id-a55f9d343f0fa22ea0031b5493036375b32f5a9e4dca90a729fe0aff282059db">
# <div class="view-content">
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"><a href="/accidents-and-incidents/e50p-berlin-schonefeld-germany-2013" hreflang="und">E50P, Berlin Schönefeld Germany, 2013</a></span></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents-map field-type-ds field-label-hidden">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Map</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_2 js-view-dom-id-c44c5e862d6c092b4686a6451e5a8538b595572039fcbef3af3e2af69cf08758">
# <div class="view-content">
# <div id="leaflet-map-view-operator-accidents-block-2--2" style="min-width: 150px; height: 500px"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>]
# {}
# {}
# PARSING: https://skybrary.aero/operator/abx-air
# [<div class="group-left two_thirds">
# <div class="group-inner">
# <div class="field field-node-node-title field-name-node-title field-type-ds field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><h2>
#   ABX Air
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="group-left-bottom">
# <div class="group-inner">
# <div class="clearfix text-formatted field field-node-body field-name-body field-type-text-with-summary field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><p>ABX Air, Inc., formerly <a express="" href="/index.php/Airborne_Express" title="Airborne">Airborne Express</a>, is a cargo airline headquartered at <a href="/index.php/KILN" title="KILN">Airborne Airpark</a>, Wilmington, Ohio. ABX Air's main customer is DHL, and the vast majority of the freight it carries is for that company.</p>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents field-type-ds field-label-hidde">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Accidents &amp; Serious Incidents involving operator</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_1 js-view-dom-id-7447785934e0872152a31c2f7e9fec766b945a0d5637ea1dff8eac60e9b3520b">
# <div class="view-content">
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"></span></div></div>
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"><a href="/accidents-and-incidents/b762-san-francisco-ca-usa-2008" hreflang="und">B762, San Francisco CA USA, 2008</a></span></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents-map field-type-ds field-label-hidden">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Map</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_2 js-view-dom-id-ab016eff5b1c9fa0e828f6931f50dec0062cf5c60d656b545e787f4784888fc9">
# <div class="view-content">
# <div id="leaflet-map-view-operator-accidents-block-2--2" style="min-width: 150px; height: 500px"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>]
# {}
# {}
# PARSING: https://skybrary.aero/operator/act-airlines
# [<div class="group-left two_thirds">
# <div class="group-inner">
# <div class="field field-node-node-title field-name-node-title field-type-ds field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><h2>
#   ACT Airlines
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="group-left-bottom">
# <div class="group-inner">
# <div class="clearfix text-formatted field field-node-body field-name-body field-type-text-with-summary field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><p>Formerly branded as MyCargo Airlines, ACT Airlines is a Turkish cargo airline based in Istanbul, Turkey.</p>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents field-type-ds field-label-hidde">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Accidents &amp; Serious Incidents involving operator</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_1 js-view-dom-id-6cc525875a86824357a2be046932f89ce779c782f820fe6e9aef036519b794a6">
# <div class="view-content">
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"><a href="/accidents-and-incidents/b744-maastricht-aachen-netherlands-2017" hreflang="und">B744, Maastricht-Aachen Netherlands, 2017</a></span></div></div>
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"><a href="/accidents-and-incidents/b744-vicinity-bishkek-kyrgyzstan-2017" hreflang="und">B744, vicinity Bishkek Kyrgyzstan, 2017</a></span></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents-map field-type-ds field-label-hidden">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Map</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_2 js-view-dom-id-e311ed483c40a4c88236792f2eebc1d0160a5711aad02fa9dc22bc048cf88329">
# <div class="view-content">
# <div id="leaflet-map-view-operator-accidents-block-2--2" style="min-width: 150px; height: 500px"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>]
# {}
# {}
# PARSING: https://skybrary.aero/operator/adam-air
# [<div class="group-left two_thirds">
# <div class="group-inner">
# <div class="field field-node-node-title field-name-node-title field-type-ds field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><h2>
#   Adam Air
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="group-left-bottom">
# <div class="group-inner">
# <div class="clearfix text-formatted field field-node-body field-name-body field-type-text-with-summary field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><p>Adam Air, (incorporated as PT. Adam SkyConnection Airlines), was a privately owned airline based in West Jakarta, Jakarta, Indonesia. It operated scheduled domestic services to over 20 cities and international services to Penang and Singapore.</p>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents field-type-ds field-label-hidde">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Accidents &amp; Serious Incidents involving operator</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_1 js-view-dom-id-74f3f538ad998430b623632d6dbfdb721607b17ec321bef261ebfcc70550b94d">
# <div class="view-content">
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"><a href="/accidents-and-incidents/b734-en-route-sulawesi-indonesia-2007" hreflang="und">B734, en-route, Sulawesi Indonesia, 2007</a></span></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents-map field-type-ds field-label-hidden">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Map</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_2 js-view-dom-id-17df48a8c87a11948870634d820abb526d618713e42cbff4e626fbafc24a09a1">
# <div class="view-content">
# <div id="leaflet-map-view-operator-accidents-block-2--2" style="min-width: 150px; height: 500px"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>]
# {}
# {}
# PARSING: https://skybrary.aero/operator/adc-airlines
# [<div class="group-left two_thirds">
# <div class="group-inner">
# <div class="field field-node-node-title field-name-node-title field-type-ds field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><h2>
#   ADC Airlines
# </h2>
# </div>
# </div>
# </div>
# </div>
# </div>, <div class="group-left-bottom">
# <div class="group-inner">
# <div class="clearfix text-formatted field field-node-body field-name-body field-type-text-with-summary field-label-hidden has-single">
# <div class="field-items">
# <div class="field-item"><p>ADC Airlines was a Nigerian airline owned by Aviation Development Company plc and headquartered in Ikeja, Lagos State, Nigeria. It operated domestic scheduled services and regional charter flights. It had applied to be designated on international routes. Its main base was Murtala Mohammed International Airport, Lagos.</p>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents field-type-ds field-label-hidde">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Accidents &amp; Serious Incidents involving operator</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_1 js-view-dom-id-08da47a1136fda765986b61b65e8d6fd237902447b0b7a09daaee99ab2c899d6">
# <div class="view-content">
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"></span></div></div>
# <div class="views-row"><div class="views-field views-field-title"><span class="field-content"><a href="/accidents-and-incidents/b732-vicinity-abuja-nigeria-2006" hreflang="und">B732, vicinity Abuja Nigeria, 2006</a></span></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="field field-name-operator-accidents-map field-type-ds field-label-hidden">
# <div class="field-items">
# <div class="field-item">
# <div class="block block-views">
# <h2>Map</h2>
# <div class="content">
# <div class="views-element-container"><div class="view view-operator-accidents view-id-operator_accidents view-display-id-block_2 js-view-dom-id-dfc6a5f34db350f613217eddc180d6a7e574f3356118504257ea6f5d3fbaa43c">
# <div class="view-content">
# <div id="leaflet-map-view-operator-accidents-block-2--2" style="min-width: 150px; height: 500px"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>]
# {}
# {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 3
#       1 # AIRCRAFT OPERATORS
#       2 print(array_browsers[4])
# ----> 3 ParserCategory(array_browsers[4][0], array_browsers[4][1])
#
# Cell In[55], line 32, in ParserCategory(URL, name_category)
#      29 for article in articles:
#      31     URL_article = "https://skybrary.aero" + article.find("a")["href"]
# ---> 32     webSite_article = requests.get(URL_article)
#      33     print("PARSING: "+URL_article)
#      34     soup_article = BeautifulSoup(webSite_article.content, "html.parser")
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 # Trigger any extra validation we need to do.
#     381 try:
# --> 382     self._validate_conn(conn)
#     383 except (SocketTimeout, BaseSSLError) as e:
#     384     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     385     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1012, in HTTPSConnectionPool._validate_conn(self, conn)
#    1010 # Force connect early to allow us to validate the connection.
#    1011 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1012     conn.connect()
#    1014 if not conn.is_verified:
#    1015     warnings.warn(
#    1016         (
#    1017             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1022         InsecureRequestWarning,
#    1023     )
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     402 if (
#     403     not self.ca_certs
#     404     and not self.ca_cert_dir
#    (...)
#     407     and hasattr(context, "load_default_certs")
#     408 ):
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#     427 if (
#     428     default_ssl_context
#     429     and self.ssl_version is None
#     430     and hasattr(self.sock, "version")
#     431     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     432 ):
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /usr/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /usr/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File /usr/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
themes_page = requests.get(dict_navigations["Themes"])
themes_soup = BeautifulSoup(themes_page.content, "html.parser")

# find all <a> tags in div with class="filed-item"
themes = themes_soup.find("div", class_="group-inner").find_all("a")
themes

array_themes=[]
for theme in themes:
    array_themes.append([URL + theme["href"], theme.text.strip()])

array_themes
# Out:
# [['https://skybrary.aero/themes/annual-safety-forums', 'Annual Safety Forums'],
#  ['https://skybrary.aero/cast-safety-enhancement-plan',
#   'CAST Safety Enhancement Plan'],
#  ['https://skybrary.aero/safety-regulations/single-european-sky',
#   'Single European Sky'],
#  ['https://skybrary.aero/glossary', 'Glossary'],
#  ['https://skybrary.aero/general-aviation', 'General Aviation']]

# %%
# GENERAL AVIATION
print(array_themes[4])
ParserCategory(array_themes[4][0], array_themes[4][1])
# Out:
# ['https://skybrary.aero/general-aviation', 'General Aviation']
# PARSING: https://skybrary.aero/general-aviation
# Number of articles: 53
# https://skybrary.aero/articles/airspace-infringement
# https://skybrary.aero/articles/airspace-infringement-and-navigation
# https://skybrary.aero/articles/airspace-infringement-guidance-notes-ga-pilots
# https://skybrary.aero/articles/altimeter
# https://skybrary.aero/articles/altimeter-temperature-error-correction
# https://skybrary.aero/articles/association-professional-warbird-operators-apwo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # GENERAL AVIATION
#       2 print(array_themes[4])
# ----> 3 ParserCategory(array_themes[4][0], array_themes[4][1])
#
# File ~/Documents/EUROCONTROL/WebScrapping/functions.py:41, in ParserCategory(URL, name_category)
#      38 for article in articles:
#      40     URL_article = "https://skybrary.aero" + article.find("a")["href"]
# ---> 41     webSite_article = requests.get(URL_article)
#      42     soup_article = BeautifulSoup(webSite_article.content, "html.parser")
#      44     print(URL_article)
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:382, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380 # Trigger any extra validation we need to do.
#     381 try:
# --> 382     self._validate_conn(conn)
#     383 except (SocketTimeout, BaseSSLError) as e:
#     384     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     385     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1012, in HTTPSConnectionPool._validate_conn(self, conn)
#    1010 # Force connect early to allow us to validate the connection.
#    1011 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1012     conn.connect()
#    1014 if not conn.is_verified:
#    1015     warnings.warn(
#    1016         (
#    1017             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1022         InsecureRequestWarning,
#    1023     )
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:411, in HTTPSConnection.connect(self)
#     402 if (
#     403     not self.ca_certs
#     404     and not self.ca_cert_dir
#    (...)
#     407     and hasattr(context, "load_default_certs")
#     408 ):
#     409     context.load_default_certs()
# --> 411 self.sock = ssl_wrap_socket(
#     412     sock=conn,
#     413     keyfile=self.key_file,
#     414     certfile=self.cert_file,
#     415     key_password=self.key_password,
#     416     ca_certs=self.ca_certs,
#     417     ca_cert_dir=self.ca_cert_dir,
#     418     ca_cert_data=self.ca_cert_data,
#     419     server_hostname=server_hostname,
#     420     ssl_context=context,
#     421     tls_in_tls=tls_in_tls,
#     422 )
#     424 # If we're using all defaults and the connection
#     425 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     426 # for the host.
#     427 if (
#     428     default_ssl_context
#     429     and self.ssl_version is None
#     430     and hasattr(self.sock, "version")
#     431     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     432 ):
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /usr/lib/python3/dist-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /usr/lib/python3.11/ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File /usr/lib/python3.11/ssl.py:1075, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1072         if timeout == 0.0:
#    1073             # non-blocking
#    1074             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1075         self.do_handshake()
#    1076 except (OSError, ValueError):
#    1077     self.close()
#
# File /usr/lib/python3.11/ssl.py:1346, in SSLSocket.do_handshake(self, block)
#    1344     if timeout == 0.0 and block:
#    1345         self.settimeout(None)
# -> 1346     self._sslobj.do_handshake()
#    1347 finally:
#    1348     self.settimeout(timeout)
#
# KeyboardInterrupt:
